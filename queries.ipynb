# %%
#Queries
1. Show me black leather handbags under 2000
2. Need a purse below 2000
3. Looking for a red leather bag
4. Show black wallets
5. Gold clutch under 2000

#Semantic Search
1.Need something elegant for a wedding
2.Luxury black accessory

# %%
Streamlit
   ↓
POST /search
   ↓
FastAPI
   ↓
search_service.py
   ↓
Postgres/Chroma
   ↓
JSON Response
   ↓
Streamlit UI

# %%
#Architecture

WhatsApp
   |
Twilio WhatsApp API
   |
FastAPI Backend
   |
Llama 3
   |
Product Search
   |
PostgreSQL


MVP uses Streamlit UI.
Production uses WhatsApp Business API via Twilio.

# %%
WhatsApp User
      |
      v
WhatsApp Business API
      |
      v
FastAPI Backend
      |
      +----> Llama 3
      |
      +----> Product Search
      |
      +----> PostgreSQL
      |
      v
Response

# %%
Sales Team
|
v
WhatsApp Business API
|
v
Backend Service (FastAPI)
|
+-----> Llama 3 (Ollama)
|           |
|           v
|      Filter Extraction
|
+-----> Product Search Layer
|
v
Product Catalog
(PostgreSQL)

```
               ^
               |
       Data Ingestion Layer
               |
               v
      OneDrive / SharePoint
```
